# %%
import os
from PIL import Image

def convert_jpg_to_webp(folder_path):
    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"The folder {folder_path} does not exist.")
        return

    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is a JPG image
        if filename.endswith(".jpg"):
            # Construct full file path
            file_path = os.path.join(folder_path, filename)
            # Open the image
            with Image.open(file_path) as img:
                # Define the new filename with .webp extension
                new_filename = filename[:-4] + ".webp"
                new_file_path = os.path.join(folder_path, new_filename)
                # Convert and save the image as WEBP
                img.save(new_file_path, "WEBP")
                print(f"Converted and saved {new_filename}")

# Example usage
folder_path = '/Users/abdul/Documents/image'
convert_jpg_to_webp(folder_path)
# Out:
# Converted and saved Hazen_Intro V4_00118.webp
# Converted and saved Hazen_Intro V4_00130.webp
# Converted and saved Hazen_Intro V4_00124.webp
# Converted and saved Hazen_Intro V4_00078.webp
# Converted and saved Hazen_Intro V4_00044.webp
# Converted and saved Hazen_Intro V4_00050.webp
# Converted and saved Hazen_Intro V4_00087.webp
# Converted and saved Hazen_Intro V4_00093.webp
# Converted and saved Hazen_Intro V4_00092.webp
# Converted and saved Hazen_Intro V4_00086.webp
# Converted and saved Hazen_Intro V4_00051.webp
# Converted and saved Hazen_Intro V4_00045.webp
# Converted and saved Hazen_Intro V4_00079.webp
# Converted and saved Hazen_Intro V4_00125.webp
# Converted and saved Hazen_Intro V4_00131.webp
# Converted and saved Hazen_Intro V4_00119.webp
# Converted and saved Hazen_Intro V4_00127.webp
# Converted and saved Hazen_Intro V4_00133.webp
# Converted and saved Hazen_Intro V4_00053.webp
# Converted and saved Hazen_Intro V4_00047.webp
# ...

# %%
import os

def remove_jpg_files(folder_path):
    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"The folder {folder_path} does not exist.")
        return

    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        # Check if the file is a JPG image
        if filename.endswith(".jpg"):
            # Construct full file path
            file_path = os.path.join(folder_path, filename)
            # Remove the JPG file
            os.remove(file_path)
            print(f"Removed {filename}")

# Example usage
remove_jpg_files(folder_path)
# Out:
# Removed Hazen_Intro V4_00118.jpg
# Removed Hazen_Intro V4_00130.jpg
# Removed Hazen_Intro V4_00124.jpg
# Removed Hazen_Intro V4_00078.jpg
# Removed Hazen_Intro V4_00044.jpg
# Removed Hazen_Intro V4_00050.jpg
# Removed Hazen_Intro V4_00087.jpg
# Removed Hazen_Intro V4_00093.jpg
# Removed Hazen_Intro V4_00092.jpg
# Removed Hazen_Intro V4_00086.jpg
# Removed Hazen_Intro V4_00051.jpg
# Removed Hazen_Intro V4_00045.jpg
# Removed Hazen_Intro V4_00079.jpg
# Removed Hazen_Intro V4_00125.jpg
# Removed Hazen_Intro V4_00131.jpg
# Removed Hazen_Intro V4_00119.jpg
# Removed Hazen_Intro V4_00127.jpg
# Removed Hazen_Intro V4_00133.jpg
# Removed Hazen_Intro V4_00053.jpg
# Removed Hazen_Intro V4_00047.jpg
# Removed Hazen_Intro V4_00090.jpg
# Removed Hazen_Intro V4_00084.jpg
# Removed Hazen_Intro V4_00085.jpg
# Removed Hazen_Intro V4_00091.jpg
# Removed Hazen_Intro V4_00046.jpg
# Removed Hazen_Intro V4_00052.jpg
# Removed Hazen_Intro V4_00132.jpg
# Removed Hazen_Intro V4_00126.jpg
# ...

# %%
pip install cloudinary
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cloudinary: filename=cloudinary-1.39.1-py3-none-any.whl size=139603 sha256=2d3bfa7cb761707b2b9019eedfe9724dd54f8319893b77a671181e24ddea10b3
#   Stored in directory: /Users/abdul/Library/Caches/pip/wheels/71/e6/74/4a26304af57feb3be4577fe0c0aa921abab731e671af7a025f
# Successfully built cloudinary
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cloudinary.uploader
import cloudinary
import os

# Configure Cloudinary with your credentials
cloudinary.config( 
  cloud_name = "dn9pwzu2b", 
  api_key = "538251193933669", 
  api_secret = "ty_D-ozlIBP3o9zHmOwdKT8smbA"
)

# The path to your folder of images
folder_path = "image/"

# List all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".webp"):  # Check if the file is a .webp image
        file_path = os.path.join(folder_path, filename)
        # Upload the image to Cloudinary
        response = cloudinary.uploader.upload(file_path, 
                                              use_filename=True, 
                                              unique_filename=False,
                                              folder="image")  # Optional: Specify a folder in Cloudinary
        print(f"Uploaded {filename} with response: {response}")
# Out:
# Uploaded Hazen_Intro V4_00119.webp with response: {'asset_id': '0b73897a531ac1f1ea92d006e9cd24f5', 'public_id': 'image/Hazen_Intro_V4_00119', 'version': 1711072670, 'version_id': 'b92bb04cdc1500b36476dd0facf3db7d', 'signature': '923c0b6b8a55569dd04cb62125e940c3e0a48e0f', 'width': 3840, 'height': 2160, 'format': 'webp', 'resource_type': 'image', 'created_at': '2024-03-22T01:57:50Z', 'tags': [], 'pages': 1, 'bytes': 153924, 'type': 'upload', 'etag': '10ab22b3ae00a8b1d683f21c7a67ae3b', 'placeholder': False, 'url': 'http://res.cloudinary.com/dn9pwzu2b/image/upload/v1711072670/image/Hazen_Intro_V4_00119.webp', 'secure_url': 'https://res.cloudinary.com/dn9pwzu2b/image/upload/v1711072670/image/Hazen_Intro_V4_00119.webp', 'folder': 'image', 'original_filename': 'Hazen_Intro V4_00119', 'api_key': '538251193933669'}
# ...
